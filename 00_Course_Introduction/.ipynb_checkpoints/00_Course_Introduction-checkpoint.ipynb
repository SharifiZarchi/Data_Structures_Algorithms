# %% [markdown]
# <div style="direction:rtl;line-height:300%;"><font face="XB Zar" size=5>
# <div align=center>
#     <font face="IranNastaliq" size=30>
#     <p></p>
#     به نام خدا
#     </font>
#     <br>
#     <br>
#     <font color=#FF7500>
#     دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#     </font>
#     <br><br>
#     <font color=blue>
#     داده‌ساختارها و الگوریتم‌ها
#     </font>
#     <br><br>
#     ترم دوم سال تحصیلی ۱۳۹۷-۱۳۹۶
# </div>
#
#
#
# <hr/>
# <font color=#ff6600><h3>
# تیم تدریس:<br/></h3>
# </font>
# محمدامین برقعی،
# غزل ابراهیمی،
# فاطمه باقری،
# مهدی قربانی،
# پارسا میرطاهری،
# یاسمین طباطبایی،<br/>
# امیرمحسن آهنچی،
# حسین بیگی،
# آرش پوردامغانی،
# محمد‌مهدی جهان‌آرا،
# پیمان جبارزاده گنجه،<br/>
# محمدجواد حاجی علیخانی،
# پارسوآ خورسند رحیم زاده،
# ياشار دبيران،
# ایلیاد رمضانی،
# محمد روغنی،
# رضا سلطانی،<br/>
# سروش عبادیان،
# فرزاد عبدالحسینی،
# آرزو فاطمی،
# امیر کفشدار گوهرشادی،
# پویا مصدق،
# امیرکیوان محتشمی،<br/>
# حامد شیرزاد،
# درناسادات عبدالعظیمی،
# محسن فردوسی،
# رسول اخوان مهدوی،
# ریحانه کریمی پور،
# امیررضا مزینی،<br/>
# ایمان جامی مقدم،
# میلاد آقاجوهری،
# آریا کوثری،
# فاطمه علی‌پور،
# کیانوش عباسی،
# بهار سلامتیان،<br/>
# محمد حسام نیک پی،
# امیرحسین پویا،
# علی شریفی زارچی
#
# <p></p>
# <font color=#ff6600><h3>
# گروه پیاتزا :<br/></h3>
# </font> https://piazza.com/class/jdh5v2yiup16t6
# <p></p>
# <font color=#ff6600><h3>
# کتاب :
# </h3></font>
# <ul>
# <li>دکتر محمد قدسی، داده‌ساختارها و مبانی الگوریتم‌ها
# <li>Cormen et al., Introduction to algorithms
# <li>Udi Manber, Introduction to algorithms, a creative approach
# </ul>
# <p></p>
# <font color=#ff6600><h3>
# فعالیت‌های درس :
# </h3></font>
# <ul>
# <li>تمرین‌های نظری هفتگی
# <li>پنج سری تمرین عملی (۵ نمره)
# <li>کوییز آموزشی (۱ نمره)
# <li>کوییز از ۶  تمرین نظری (۳ نمره)
# <li>آزمون میان‌ترم نظری (۴ نمره)
# <li>دو آزمون میان‌ترم عملی (۳+۱ نمره، آزمون بهتر: ۳)
# <li>محتوای آموزشی (۱ نمره)
# <li>آزمون پایان‌ترم (۵نمره)
# </ul>
# <p></p>
# <font color=#ff6600><h3>
# این درس را بگیرید اگر :
# </h3></font>
# <ul>
# <li> علاقه دارید داده‌ساختارها را در عمل یاد بگیرید
# <li> می‌خواهید لذت یادگیری Python را تجربه کنید
# </ul>
# <p></p>
# <font color=#ff6600><h3>
# این درس را حذف کنید اگر :
# </h3></font>
# <ul>
# <li> می‌خواهید تمرین یا امتحان راکُپ بزنید/بدهید
# <li> به نمودار یا نمره‌گرفتن از طریق مذاکره امیدوار هستید
# </ul>
# <p></p>
# <div align=center>
# <font color=blue>
# حق کپی: Creative Commons BY NC. استفاده یا انتشار این مطالب برای مقاصد غیر تجاری با ذکر منبع مجاز است.
# </font>
# </div>
# </font>
# </div>
