# %% [markdown]
# <div style="direction:rtl;line-height:300%;"><font face="XB Zar" size=5>
# <div align=center>
#     <font face="IranNastaliq" size=30>
#     <p></p>
#     به نام خدا
#     </font>
#     <br>
#     <br>
#     <font color=#FF7500>
#     دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#     </font>
#     <br><br>
#     <font color=blue>
#     داده‌ساختارها و الگوریتم‌ها
#     </font>
#     <br><br>
#     ترم دوم سال تحصیلی ۱۳۹۸-۱۳۹۷
# </div>
#
#
#
# <hr/>
# <font color=#ff6600><h3>
# تیم تدریس:<br/></h3>
# </font>
# علی شریفی زارچی، کیانوش عباسی، آریا کوثری، شبنم شیخ‌ها، متین خواجوی، امیرحسین ملکی، عرفان فرهادی، علیرضا اکبری، حسین ابراهیمی، محمدرضا احمدخانی‌ها، کیارش بنی‌هاشم، امیرمجبتی صبور، پدرام خورسندی، علیرضا موسوی، روزبه مشکین‌نژاد، حمیدرضا هدایتی، صادق مهدوی، آراد محمدی
#
#
# <p></p>
# <font color=#ff6600><h3>
# کتاب :
# </h3></font>
# <ul>
# <li>دکتر محمد قدسی، داده‌ساختارها و مبانی الگوریتم‌ها
# <li>Cormen et al., Introduction to algorithms
# <li>Udi Manber, Introduction to algorithms, a creative approach
# </ul>
# <p></p>
#
#
# <font color=#ff6600><h3>
# لینک ثبت‌نام در گروه پیاتزای درس :<br/></h3>
# </font> <a href="piazza.com/sharif/spring2019/ds98"> piazza.com/sharif/spring2019/ds98 </a>
# <p></p>
# <font color=#ff6600><h3>
# رمز عبور به کلاس درس در کوئرا :<br/></h3>
# </font> sathsathsahtsath
# <p></p>
# <font color=#ff6600><h3>
# تقویم درس در گوگل :<br/></h3>
# </font> <a href="https://calendar.google.com/calendar?cid=ZTVwYTM1amkwaHQxamR2ZWVpcmxwNHZjZ2tAZ3JvdXAuY2FsZW5kYXIuZ29vZ2xlLmNvbQ"> لینک
# </a><p></p>
#
#
# <font color=#ff6600><h3>
# فعالیت‌های درس :
# </h3></font>
# <ul>
# <li>شش بسته تمرینی
# <ul><li>تمرین‌های نظری
#     <li>تمرین‌های عملی (۴ نمره)
#     </ul>
# <li>کوییز تصادفی (۱ نمره)
# <li>چهار کوییز با اعلام قبلی از تمرین‌های نظری (۳ نمره، کوییز با کمترین نمره حذف می‌شود)
# <li>دو آزمون میان‌ترم نظری  (۱.۵ + ۲.۵، آزمون بهتر: ۲.۵)
# <li>دو آزمون میان‌ترم عملی (۳+۱ نمره، آزمون بهتر: ۳)
# <li>آزمون پایان‌ترم (۶ نمره)
# </ul>
# <p></p>
# <font color=#ff6600><h3>
# این درس را بگیرید اگر :
# </h3></font>
# <ul>
# <li> علاقه دارید داده‌ساختارها را در عمل یاد بگیرید
# <li> می‌خواهید لذت یادگیری Python را تجربه کنید
# </ul>
# <p></p>
# <font color=#ff6600><h3>
# این درس را حذف کنید اگر :
# </h3></font>
# <ul>
# <li> می‌خواهید تمرین یا امتحان راکُپ بزنید/بدهید
# <li> به نمودار یا نمره‌گرفتن از طریق مذاکره امیدوار هستید
# </ul>
# <p></p>
# <div align=center>
# </div>
# </font>
# </div>
